# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# **Dataset**

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from IPython.display import Markdown

spark = SparkSession.builder.appName("RecommendationSystem").getOrCreate()

file_path = "/content/12_movielens_ratings.csv"

df = spark.read.csv(file_path, header=True, inferSchema=True)

# %%
df.show()
# Out:
# +-------+------+------+
# |movieId|rating|userId|
# +-------+------+------+
# |      2|   3.0|     0|
# |      3|   1.0|     0|
# |      5|   2.0|     0|
# |      9|   4.0|     0|
# |     11|   1.0|     0|
# |     12|   2.0|     0|
# |     15|   1.0|     0|
# |     17|   1.0|     0|
# |     19|   1.0|     0|
# |     21|   1.0|     0|
# |     23|   1.0|     0|
# |     26|   3.0|     0|
# |     27|   1.0|     0|
# |     28|   1.0|     0|
# |     29|   1.0|     0|
# |     30|   1.0|     0|
# |     31|   1.0|     0|
# |     34|   1.0|     0|
# |     37|   1.0|     0|
# |     41|   2.0|     0|
# +-------+------+------+
# only showing top 20 rows

# %%
df.describe().show()
# Out:
# +-------+------------------+------------------+------------------+
# |summary|           movieId|            rating|            userId|
# +-------+------------------+------------------+------------------+
# |  count|              1501|              1501|              1501|
# |   mean| 49.40572951365756|1.7741505662891406|14.383744170552964|
# | stddev|28.937034065088994| 1.187276166124803| 8.591040424293272|
# |    min|                 0|               1.0|                 0|
# |    max|                99|               5.0|                29|
# +-------+------------------+------------------+------------------+

# %% [markdown]
# **Jaccard Similarity**

# %%
while True:
    try:
        user_input = int(input("Enter User ID (between 0 and 29): "))

        if 0 <= user_input <= 29:
            break
        else:
            print("Please enter a User ID between 0 and 29.")

    except ValueError:

        print("Invalid input. Please enter a valid integer.")
# Out:
# Enter User ID (between 0 and 29): 0

# %%
max_similarity = 0
max_similarity_user = None

df_user_0 = df.filter(df.userId == user_input)

for i in range(0, 30):
    if i == user_input:
        continue

    df_user_1 = df.filter(df.userId == i)
    joined_df = df_user_0.join(df_user_1, "movieId")
    joined_df1 = df_user_0.join(df_user_1, "movieId", how="full_outer")
    total_count = joined_df.count()
    total_count1 = joined_df1.count()
    print("Total common Movie Ratings Between UserID",user_input,"And UserID",i,"(Intersection):", total_count)
    print("Count of all Movie Ratings Between UserID",user_input,"And UserID",i,"(Union):", total_count1)

    jaccardsimilarity = total_count / total_count1
    print("\033[1mJaccard Similarity between UserID", user_input, "and UserID {}:\033[0m {}".format(i, jaccardsimilarity))

    if jaccardsimilarity > max_similarity:
        max_similarity = jaccardsimilarity
        max_similarity_user = i
# Out:
# Total common Movie Ratings Between UserID 0 And UserID 1 (Intersection): 22
# Count of all Movie Ratings Between UserID 0 And UserID 1 (Union): 76
# Jaccard Similarity between UserID 0 and UserID 1: 0.2894736842105263
# Total common Movie Ratings Between UserID 0 And UserID 2 (Intersection): 22
# Count of all Movie Ratings Between UserID 0 And UserID 2 (Union): 73
# Jaccard Similarity between UserID 0 and UserID 2: 0.3013698630136986
# Total common Movie Ratings Between UserID 0 And UserID 3 (Intersection): 21
# Count of all Movie Ratings Between UserID 0 And UserID 3 (Union): 76
# Jaccard Similarity between UserID 0 and UserID 3: 0.27631578947368424
# Total common Movie Ratings Between UserID 0 And UserID 4 (Intersection): 28
# Count of all Movie Ratings Between UserID 0 And UserID 4 (Union): 76
# Jaccard Similarity between UserID 0 and UserID 4: 0.3684210526315789
# Total common Movie Ratings Between UserID 0 And UserID 5 (Intersection): 24
# Count of all Movie Ratings Between UserID 0 And UserID 5 (Union): 74
# Jaccard Similarity between UserID 0 and UserID 5: 0.32432432432432434
# Total common Movie Ratings Between UserID 0 And UserID 6 (Intersection): 29
# Count of all Movie Ratings Between UserID 0 And UserID 6 (Union): 77
# Jaccard Similarity between UserID 0 and UserID 6: 0.37662337662337664
# Total common Movie Ratings Between UserID 0 And UserID 7 (Intersection): 24
# Count of all Movie Ratings Between UserID 0 And UserID 7 (Union): 79
# Jaccard Similarity between UserID 0 and UserID 7: 0.3037974683544304
# Total common Movie Ratings Between UserID 0 And UserID 8 (Intersection): 29
# Count of all Movie Ratings Between UserID 0 And UserID 8 (Union): 69
# Jaccard Similarity between UserID 0 and UserID 8: 0.42028985507246375
# Total common Movie Ratings Between UserID 0 And UserID 9 (Intersection): 25
# Count of all Movie Ratings Between UserID 0 And UserID 9 (Union): 77
# Jaccard Similarity between UserID 0 and UserID 9: 0.3246753246753247
# Total common Movie Ratings Between UserID 0 And UserID 10 (Intersection): 15
# Count of all Movie Ratings Between UserID 0 And UserID 10 (Union): 78
# Jaccard Similarity between UserID 0 and UserID 10: 0.19230769230769232
# Total common Movie Ratings Between UserID 0 And UserID 11 (Intersection): 27
# Count of all Movie Ratings Between UserID 0 And UserID 11 (Union): 78
# Jaccard Similarity between UserID 0 and UserID 11: 0.34615384615384615
# Total common Movie Ratings Between UserID 0 And UserID 12 (Intersection): 27
# Count of all Movie Ratings Between UserID 0 And UserID 12 (Union): 77
# Jaccard Similarity between UserID 0 and UserID 12: 0.35064935064935066
# Total common Movie Ratings Between UserID 0 And UserID 13 (Intersection): 25
# Count of all Movie Ratings Between UserID 0 And UserID 13 (Union): 72
# Jaccard Similarity between UserID 0 and UserID 13: 0.3472222222222222
# Total common Movie Ratings Between UserID 0 And UserID 14 (Intersection): 32
# Count of all Movie Ratings Between UserID 0 And UserID 14 (Union): 74
# Jaccard Similarity between UserID 0 and UserID 14: 0.43243243243243246
# Total common Movie Ratings Between UserID 0 And UserID 15 (Intersection): 23
# Count of all Movie Ratings Between UserID 0 And UserID 15 (Union): 74
# Jaccard Similarity between UserID 0 and UserID 15: 0.3108108108108108
# Total common Movie Ratings Between UserID 0 And UserID 16 (Intersection): 25
# Count of all Movie Ratings Between UserID 0 And UserID 16 (Union): 69
# Jaccard Similarity between UserID 0 and UserID 16: 0.36231884057971014
# Total common Movie Ratings Between UserID 0 And UserID 17 (Intersection): 23
# Count of all Movie Ratings Between UserID 0 And UserID 17 (Union): 72
# Jaccard Similarity between UserID 0 and UserID 17: 0.3194444444444444
# Total common Movie Ratings Between UserID 0 And UserID 18 (Intersection): 22
# Count of all Movie Ratings Between UserID 0 And UserID 18 (Union): 79
# Jaccard Similarity between UserID 0 and UserID 18: 0.27848101265822783
# Total common Movie Ratings Between UserID 0 And UserID 19 (Intersection): 24
# Count of all Movie Ratings Between UserID 0 And UserID 19 (Union): 74
# Jaccard Similarity between UserID 0 and UserID 19: 0.32432432432432434
# Total common Movie Ratings Between UserID 0 And UserID 20 (Intersection): 21
# Count of all Movie Ratings Between UserID 0 And UserID 20 (Union): 75
# Jaccard Similarity between UserID 0 and UserID 20: 0.28
# Total common Movie Ratings Between UserID 0 And UserID 21 (Intersection): 28
# Count of all Movie Ratings Between UserID 0 And UserID 21 (Union): 69
# Jaccard Similarity between UserID 0 and UserID 21: 0.4057971014492754
# Total common Movie Ratings Between UserID 0 And UserID 22 (Intersection): 25
# Count of all Movie Ratings Between UserID 0 And UserID 22 (Union): 80
# Jaccard Similarity between UserID 0 and UserID 22: 0.3125
# Total common Movie Ratings Between UserID 0 And UserID 23 (Intersection): 24
# Count of all Movie Ratings Between UserID 0 And UserID 23 (Union): 77
# Jaccard Similarity between UserID 0 and UserID 23: 0.3116883116883117
# Total common Movie Ratings Between UserID 0 And UserID 24 (Intersection): 28
# Count of all Movie Ratings Between UserID 0 And UserID 24 (Union): 73
# Jaccard Similarity between UserID 0 and UserID 24: 0.3835616438356164
# Total common Movie Ratings Between UserID 0 And UserID 25 (Intersection): 24
# Count of all Movie Ratings Between UserID 0 And UserID 25 (Union): 71
# Jaccard Similarity between UserID 0 and UserID 25: 0.3380281690140845
# Total common Movie Ratings Between UserID 0 And UserID 26 (Intersection): 21
# Count of all Movie Ratings Between UserID 0 And UserID 26 (Union): 77
# Jaccard Similarity between UserID 0 and UserID 26: 0.2727272727272727
# Total common Movie Ratings Between UserID 0 And UserID 27 (Intersection): 23
# Count of all Movie Ratings Between UserID 0 And UserID 27 (Union): 72
# Jaccard Similarity between UserID 0 and UserID 27: 0.3194444444444444
# Total common Movie Ratings Between UserID 0 And UserID 28 (Intersection): 22
# Count of all Movie Ratings Between UserID 0 And UserID 28 (Union): 77
# Jaccard Similarity between UserID 0 and UserID 28: 0.2857142857142857
# Total common Movie Ratings Between UserID 0 And UserID 29 (Intersection): 21
# Count of all Movie Ratings Between UserID 0 And UserID 29 (Union): 74
# Jaccard Similarity between UserID 0 and UserID 29: 0.28378378378378377

# %%
print("User ID with the highest Jaccard similarity to UserID", user_input, "is:", max_similarity_user)
print("Highest Jaccard Similarity:", max_similarity)
# Out:
# User ID with the highest Jaccard similarity to UserID 0 is: 14
# Highest Jaccard Similarity: 0.43243243243243246

# %% [markdown]
# **Cosine Similarity**

# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import col, expr, sqrt
while True:
    try:
        user_input = int(input("Enter User ID (between 0 and 29): "))


        if 0 <= user_input <= 29:
            break
        else:
            print("Please enter a User ID between 0 and 29.")

    except ValueError:

        print("Invalid input. Please enter a valid integer.")
# Out:
# Enter User ID (between 0 and 29): 0

# %%
max_similarity = 0
max_similarity_user = None

df_user0 = df.filter(F.col("userId") == user_input).select("movieId", "rating").withColumnRenamed("rating", "rating_0")

for i in range(0, 30):
  if i == user_input:
    continue
  df_user1 = df.filter(F.col("userId") == i).select("movieId", "rating").withColumnRenamed("rating", "rating_1")
  joined_df = df_user0.join(df_user1, on="movieId")

  result = joined_df.withColumn("rating_product", F.col("rating_0") * F.col("rating_1")) \
                     .groupBy().sum("rating_product") \
                     .collect()[0][0]
  #df_user1.show()
  print("\033[1mΣk=1 xkyk:\033[0m {}".format(result))

  df_user_0 = df.filter(df.userId == user_input)
  df_squared1 = df_user_0.withColumn("rating_squared", col("rating") ** 2)
  df_grouped1 = df_squared1.groupBy("userId").agg(expr("sqrt(sum(rating_squared))").alias("sqrt_sum_ratings"))
  results1=df_grouped1.collect()
  df_grouped1.show()
  sqrt_sum_ratings_user00 = results1[0]["sqrt_sum_ratings"]
  print('√Σk=1 xk^2:',sqrt_sum_ratings_user00)

  df_user_1 = df.filter(df.userId == i)
  df_squared1 = df_user_1.withColumn("rating_squared", col("rating") ** 2)
  df_grouped1 = df_squared1.groupBy("userId").agg(expr("sqrt(sum(rating_squared))").alias("sqrt_sum_ratings"))
  results1 = df_grouped1.collect()
  sqrt_sum_ratings_user01 = results1[0]["sqrt_sum_ratings"]
  print('√Σk=1 yk^2:',sqrt_sum_ratings_user01)
  df_grouped1.show()
  a = sqrt_sum_ratings_user00 * sqrt_sum_ratings_user01
  print("\033[1m√Σk=1 xk^2 * yk^2:\033[0m {}".format(a))

  cosine = result / a

  print("\033[1mCosine similarity between UserID", user_input, "and UserID {}:\033[0m {}".format(i, cosine))
  print("\n")
  if cosine > max_similarity:
    max_similarity = cosine
    max_similarity_user = i
# Out:
# Σk=1 xkyk: 64.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 12.328828005937952
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |     1|12.328828005937952|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 140.5702671264446
# Cosine similarity between UserID 0 and UserID 1: 0.45528831457957786
#
#
# Σk=1 xkyk: 75.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 17.05872210923198
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     2|17.05872210923198|
# +------+-----------------+
#
# √Σk=1 xk^2 * yk^2: 194.49935732541636
# Cosine similarity between UserID 0 and UserID 2: 0.38560538724309357
#
#
# Σk=1 xkyk: 46.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 14.832396974191326
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |     3|14.832396974191326|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 169.11534525287763
# Cosine similarity between UserID 0 and UserID 3: 0.272003702154978
#
#
# Σk=1 xkyk: 50.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 13.711309200802088
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |     4|13.711309200802088|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 156.3329779669024
# Cosine similarity between UserID 0 and UserID 4: 0.31983015132345016
#
#
# Σk=1 xkyk: 61.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 14.52583904633395
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     5|14.52583904633395|
# +------+-----------------+
#
# √Σk=1 xk^2 * yk^2: 165.62004709575467
# Cosine similarity between UserID 0 and UserID 5: 0.3683129009420721
#
#
# Σk=1 xkyk: 64.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 12.884098726725126
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |     6|12.884098726725126|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 146.90132742763083
# Cosine similarity between UserID 0 and UserID 6: 0.4356665873664677
#
#
# Σk=1 xkyk: 58.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 14.0
# +------+----------------+
# |userId|sqrt_sum_ratings|
# +------+----------------+
# |     7|            14.0|
# +------+----------------+
#
# √Σk=1 xk^2 * yk^2: 159.62455951387932
# Cosine similarity between UserID 0 and UserID 7: 0.3633526079986264
#
#
# Σk=1 xkyk: 77.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 16.278820596099706
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |     8|16.278820596099706|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 185.60711193270583
# Cosine similarity between UserID 0 and UserID 8: 0.41485479299908135
#
#
# Σk=1 xkyk: 61.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 15.329709716755891
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |     9|15.329709716755891|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 174.78558292948534
# Cosine similarity between UserID 0 and UserID 9: 0.3489990362912801
#
#
# Σk=1 xkyk: 37.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 11.704699910719626
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    10|11.704699910719626|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 133.4541119636259
# Cosine similarity between UserID 0 and UserID 10: 0.2772488569710364
#
#
# Σk=1 xkyk: 75.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 20.591260281974
# +------+----------------+
# |userId|sqrt_sum_ratings|
# +------+----------------+
# |    11| 20.591260281974|
# +------+----------------+
#
# √Σk=1 xk^2 * yk^2: 234.776489453267
# Cosine similarity between UserID 0 and UserID 11: 0.31945277048249326
#
#
# Σk=1 xkyk: 75.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 16.673332000533065
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    12|16.673332000533065|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 190.10523401526848
# Cosine similarity between UserID 0 and UserID 12: 0.39451833290385
#
#
# Σk=1 xkyk: 41.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 11.874342087037917
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    13|11.874342087037917|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 135.3883303686104
# Cosine similarity between UserID 0 and UserID 13: 0.30283259929694645
#
#
# Σk=1 xkyk: 62.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 16.55294535724685
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    14|16.55294535724685|
# +------+-----------------+
#
# √Σk=1 xk^2 * yk^2: 188.73261509341728
# Cosine similarity between UserID 0 and UserID 14: 0.3285070784893844
#
#
# Σk=1 xkyk: 55.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 12.24744871391589
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    15|12.24744871391589|
# +------+-----------------+
#
# √Σk=1 xk^2 * yk^2: 139.6424004376894
# Cosine similarity between UserID 0 and UserID 15: 0.39386318072168813
#
#
# Σk=1 xkyk: 62.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 14.628738838327793
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    16|14.628738838327793|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 166.7932852365466
# Cosine similarity between UserID 0 and UserID 16: 0.37171760189309455
#
#
# Σk=1 xkyk: 59.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 16.431676725154983
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    17|16.431676725154983|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 187.34993995195194
# Cosine similarity between UserID 0 and UserID 17: 0.31491870248333803
#
#
# Σk=1 xkyk: 49.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 15.362291495737216
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    18|15.362291495737216|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 175.15707236649052
# Cosine similarity between UserID 0 and UserID 18: 0.2797489095814223
#
#
# Σk=1 xkyk: 46.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 12.083045973594572
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    19|12.083045973594572|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 137.76792079435617
# Cosine similarity between UserID 0 and UserID 19: 0.33389485545523634
#
#
# Σk=1 xkyk: 61.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 13.892443989449804
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    20|13.892443989449804|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 158.39823231336894
# Cosine similarity between UserID 0 and UserID 20: 0.38510530773676793
#
#
# Σk=1 xkyk: 66.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 14.2828568570857
# +------+----------------+
# |userId|sqrt_sum_ratings|
# +------+----------------+
# |    21|14.2828568570857|
# +------+----------------+
#
# √Σk=1 xk^2 * yk^2: 162.84962388657826
# Cosine similarity between UserID 0 and UserID 21: 0.4052818694009866
#
#
# Σk=1 xkyk: 79.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 19.261360284258224
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    22|19.261360284258224|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 219.61329650091773
# Cosine similarity between UserID 0 and UserID 22: 0.3597232101093199
#
#
# Σk=1 xkyk: 63.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 18.734993995195193
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    23|18.734993995195193|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 213.61179742701475
# Cosine similarity between UserID 0 and UserID 23: 0.2949275309643203
#
#
# Σk=1 xkyk: 73.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 16.852299546352718
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    24|16.852299546352718|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 192.1457779916072
# Cosine similarity between UserID 0 and UserID 24: 0.3799198752271757
#
#
# Σk=1 xkyk: 63.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 12.449899597988733
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    25|12.449899597988733|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 141.95069566578388
# Cosine similarity between UserID 0 and UserID 25: 0.4438160708160986
#
#
# Σk=1 xkyk: 50.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 18.547236990991408
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    26|18.547236990991408|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 211.47103820618085
# Cosine similarity between UserID 0 and UserID 26: 0.23643899620547948
#
#
# Σk=1 xkyk: 50.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 12.489995996796797
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    27|12.489995996796797|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 142.40786495134319
# Cosine similarity between UserID 0 and UserID 27: 0.35110420352895266
#
#
# Σk=1 xkyk: 77.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 15.652475842498529
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    28|15.652475842498529|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 178.46568297574746
# Cosine similarity between UserID 0 and UserID 28: 0.4314554973040049
#
#
# Σk=1 xkyk: 45.0
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|11.40175425099138|
# +------+-----------------+
#
# √Σk=1 xk^2: 11.40175425099138
# √Σk=1 yk^2: 14.560219778561036
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    29|14.560219778561036|
# +------+------------------+
#
# √Σk=1 xk^2 * yk^2: 166.01204775557704
# Cosine similarity between UserID 0 and UserID 29: 0.2710646643324009

# %%
print("User ID with the highest Cosine similarity to UserID", user_input, "is:", max_similarity_user)
print("Highest Cosine Similarity:", max_similarity)
# Out:
# User ID with the highest Cosine similarity to UserID 0 is: 1
# Highest Cosine Similarity: 0.45528831457957786

# %% [markdown]
# **Centered Cosine Similarity**

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.functions import col, expr, sqrt

csv_file_path = "/content/12_movielens_ratings.csv"
df = spark.read.csv(csv_file_path, header=True, inferSchema=True)
while True:
    try:
        user_input = int(input("Enter User ID (between 0 and 29): "))


        if 0 <= user_input <= 29:
            break
        else:
            print("Please enter a User ID between 0 and 20.")

    except ValueError:

        print("Invalid input. Please enter a valid integer.")
# Out:
# Enter User ID (between 0 and 29): 0

# %%
max_similarity = 0
max_similarity_user = None
average_result = df.filter(col("userId") == user_input).agg(avg("rating").alias("rating_avg"))
average_result.show()
average = average_result.collect()[0]["rating_avg"]
print("\nAverage rating for userId",user_input, average)
df_modified = df.withColumn("rating", col("rating") - average).filter(col("userId") == user_input)
print("\nDataFrame with ratings subtracted by the average for userId",user_input)


df_modified.show()
for i in range(0,30):
  if i == user_input:
    continue
  average_result1 = df.filter(col("userId") == i).agg(avg("rating").alias("rating_avg"))
  average1 = average_result1.collect()[0]["rating_avg"]

  print("\033[1m\nAverage rating for userId {}:\033[0m {}".format(i, average1))

  df_modified1 = df.withColumn("rating", col("rating") - average1).filter(col("userId") == i)

  print("\033[1m\nDataFrame with ratings subtracted by the average for userId {}:\033[0m".format(i))

  df_modified1.show()
  df_combined = df_modified.union(df_modified1)

  print("\033[1m\nCombined DataFrame:\033[0m")

  df_combined.show()



  df_user0 = df_combined.filter(F.col("userId") == user_input).select("movieId", "rating").withColumnRenamed("rating", "rating_0")
  df_user1 = df_combined.filter(F.col("userId") == i).select("movieId", "rating").withColumnRenamed("rating", "rating_1")
  joined_df = df_user0.join(df_user1, on="movieId")
  result = joined_df.withColumn("rating_product", F.col("rating_0") * F.col("rating_1")) \
                 .groupBy().sum("rating_product") \
                 .collect()[0][0]

  print("\033[1mΣk=1 xkyk:\033[0m {}".format(result))


  df_user_0 = df_combined.filter(df_combined.userId == user_input)
  df_squared1 = df_user_0.withColumn("rating_squared", col("rating") ** 2)
  df_grouped1 = df_squared1.groupBy("userId").agg(expr("sqrt(sum(rating_squared))").alias("sqrt_sum_ratings"))
  results1=df_grouped1.collect()
  sqrt_sum_ratings_user00 = results1[0]["sqrt_sum_ratings"]
  df_grouped1.show()
  print('√Σk=1 xk^2:',sqrt_sum_ratings_user00)
  df_user_1 = df_combined.filter(df_combined.userId == i)
  df_squared1 = df_user_1.withColumn("rating_squared", col("rating") ** 2)
  df_grouped1 = df_squared1.groupBy("userId").agg(expr("sqrt(sum(rating_squared))").alias("sqrt_sum_ratings"))
  results1=df_grouped1.collect()
  sqrt_sum_ratings_user01 = results1[0]["sqrt_sum_ratings"]
  df_grouped1.show()
  print('√Σk=1 yk^2:',sqrt_sum_ratings_user01)
  a=sqrt_sum_ratings_user00 * sqrt_sum_ratings_user01

  print("√Σk=1 xk^2 * Σk=1 xkyk",a)
  cosine=result/a
  print("Centered cosine similarity between UserID",user_input,"and UserID",i,cosine)
  if cosine > max_similarity:
    max_similarity = cosine
    max_similarity_user = i
# Out:
# +------------------+
# |        rating_avg|
# +------------------+
# |1.4285714285714286|
# +------------------+
#
#
# Average rating for userId 0 1.4285714285714286
#
# DataFrame with ratings subtracted by the average for userId 0
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Average rating for userId 1: 1.5510204081632653
#
# DataFrame with ratings subtracted by the average for userId 1:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2|0.44897959183673475|     1|
# |      3|-0.5510204081632653|     1|
# |      4|0.44897959183673475|     1|
# |      6|-0.5510204081632653|     1|
# |      9| 1.4489795918367347|     1|
# |     12|-0.5510204081632653|     1|
# |     13|-0.5510204081632653|     1|
# |     14|-0.5510204081632653|     1|
# |     16|-0.5510204081632653|     1|
# |     19|-0.5510204081632653|     1|
# |     21| 1.4489795918367347|     1|
# |     27|-0.5510204081632653|     1|
# |     28| 1.4489795918367347|     1|
# |     33|-0.5510204081632653|     1|
# |     36|0.44897959183673475|     1|
# |     37|-0.5510204081632653|     1|
# |     40|-0.5510204081632653|     1|
# |     41|0.44897959183673475|     1|
# |     43|-0.5510204081632653|     1|
# |     44|-0.5510204081632653|     1|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: 5.603498542274052
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     1|5.841442371503106|
# +------+-----------------+
#
# √Σk=1 yk^2: 5.841442371503106
# √Σk=1 xk^2 * Σk=1 xkyk 31.994897552387258
# Centered cosine similarity between UserID 0 and UserID 1 0.17513725534201482
#
# Average rating for userId 2: 2.0652173913043477
#
# DataFrame with ratings subtracted by the average for userId 2:
# +-------+--------------------+------+
# |movieId|              rating|userId|
# +-------+--------------------+------+
# |      4|  0.9347826086956523|     2|
# |      6| -1.0652173913043477|     2|
# |      8|  2.9347826086956523|     2|
# |      9| -1.0652173913043477|     2|
# |     10| -1.0652173913043477|     2|
# |     12|  0.9347826086956523|     2|
# |     13| -1.0652173913043477|     2|
# |     15|-0.06521739130434767|     2|
# |     18|-0.06521739130434767|     2|
# |     19|  1.9347826086956523|     2|
# |     22| -1.0652173913043477|     2|
# |     26| -1.0652173913043477|     2|
# |     28| -1.0652173913043477|     2|
# |     34|  1.9347826086956523|     2|
# |     35| -1.0652173913043477|     2|
# |     37|  2.9347826086956523|     2|
# |     38| -1.0652173913043477|     2|
# |     39|  2.9347826086956523|     2|
# |     40|  1.9347826086956523|     2|
# |     47| -1.0652173913043477|     2|
# +-------+--------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -0.9472049689441011
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+----------------+
# |userId|sqrt_sum_ratings|
# +------+----------------+
# |     2|9.73675242707172|
# +------+----------------+
#
# √Σk=1 yk^2: 9.73675242707172
# √Σk=1 xk^2 * Σk=1 xkyk 53.33038941150358
# Centered cosine similarity between UserID 0 and UserID 2 -0.017761073552929753
#
# Average rating for userId 3: 1.8333333333333333
#
# DataFrame with ratings subtracted by the average for userId 3:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-0.8333333333333333|     3|
# |      1|-0.8333333333333333|     3|
# |      2|-0.8333333333333333|     3|
# |      7| 1.1666666666666667|     3|
# |      8| 1.1666666666666667|     3|
# |      9|-0.8333333333333333|     3|
# |     14|-0.8333333333333333|     3|
# |     15|-0.8333333333333333|     3|
# |     16|-0.8333333333333333|     3|
# |     18|  2.166666666666667|     3|
# |     19|-0.8333333333333333|     3|
# |     24| 1.1666666666666667|     3|
# |     26|-0.8333333333333333|     3|
# |     29| 1.1666666666666667|     3|
# |     33|-0.8333333333333333|     3|
# |     34| 1.1666666666666667|     3|
# |     35|-0.8333333333333333|     3|
# |     36| 1.1666666666666667|     3|
# |     37|-0.8333333333333333|     3|
# |     38|0.16666666666666674|     3|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -7.261904761904762
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     3|7.659416862050704|
# +------+-----------------+
#
# √Σk=1 yk^2: 7.659416862050704
# √Σk=1 xk^2 * Σk=1 xkyk 41.952353926806076
# Centered cosine similarity between UserID 0 and UserID 3 -0.1730988629285152
#
# Average rating for userId 4: 1.5636363636363637
#
# DataFrame with ratings subtracted by the average for userId 4:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      1|-0.5636363636363637|     4|
# |      6|-0.5636363636363637|     4|
# |      8|-0.5636363636363637|     4|
# |      9|-0.5636363636363637|     4|
# |     10|-0.5636363636363637|     4|
# |     11|-0.5636363636363637|     4|
# |     12|-0.5636363636363637|     4|
# |     13|-0.5636363636363637|     4|
# |     14| 0.4363636363636363|     4|
# |     15|-0.5636363636363637|     4|
# |     17|-0.5636363636363637|     4|
# |     20|-0.5636363636363637|     4|
# |     22|-0.5636363636363637|     4|
# |     23|-0.5636363636363637|     4|
# |     24|-0.5636363636363637|     4|
# |     29| 2.4363636363636365|     4|
# |     30|-0.5636363636363637|     4|
# |     31|-0.5636363636363637|     4|
# |     34|-0.5636363636363637|     4|
# |     35|-0.5636363636363637|     4|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: 1.9688311688311684
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     4|7.316233506885405|
# +------+-----------------+
#
# √Σk=1 yk^2: 7.316233506885405
# √Σk=1 xk^2 * Σk=1 xkyk 40.07266127696266
# Centered cosine similarity between UserID 0 and UserID 4 0.04913153022764245
#
# Average rating for userId 5: 1.7755102040816326
#
# DataFrame with ratings subtracted by the average for userId 5:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-0.7755102040816326|     5|
# |      1|-0.7755102040816326|     5|
# |      4|-0.7755102040816326|     5|
# |      5|-0.7755102040816326|     5|
# |      8|-0.7755102040816326|     5|
# |      9| 1.2244897959183674|     5|
# |     10|0.22448979591836737|     5|
# |     13| 1.2244897959183674|     5|
# |     15|-0.7755102040816326|     5|
# |     19|-0.7755102040816326|     5|
# |     20| 1.2244897959183674|     5|
# |     21|0.22448979591836737|     5|
# |     23| 1.2244897959183674|     5|
# |     27|-0.7755102040816326|     5|
# |     28|-0.7755102040816326|     5|
# |     29|-0.7755102040816326|     5|
# |     31|-0.7755102040816326|     5|
# |     36| 1.2244897959183674|     5|
# |     38|0.22448979591836737|     5|
# |     39|-0.7755102040816326|     5|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: 2.201166180758018
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     5|7.518684209680439|
# +------+-----------------+
#
# √Σk=1 yk^2: 7.518684209680439
# √Σk=1 xk^2 * Σk=1 xkyk 41.181529443998805
# Centered cosine similarity between UserID 0 and UserID 5 0.053450326165066314
#
# Average rating for userId 6: 1.4385964912280702
#
# DataFrame with ratings subtracted by the average for userId 6:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-0.4385964912280702|     6|
# |      1|-0.4385964912280702|     6|
# |      2| 1.5614035087719298|     6|
# |      5|-0.4385964912280702|     6|
# |      6|-0.4385964912280702|     6|
# |      9|-0.4385964912280702|     6|
# |     10|-0.4385964912280702|     6|
# |     15| 0.5614035087719298|     6|
# |     16| 0.5614035087719298|     6|
# |     17|-0.4385964912280702|     6|
# |     18|-0.4385964912280702|     6|
# |     20|-0.4385964912280702|     6|
# |     21|-0.4385964912280702|     6|
# |     22|-0.4385964912280702|     6|
# |     24|-0.4385964912280702|     6|
# |     25|   3.56140350877193|     6|
# |     26|-0.4385964912280702|     6|
# |     28|-0.4385964912280702|     6|
# |     30|-0.4385964912280702|     6|
# |     33|-0.4385964912280702|     6|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: 3.147869674185464
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     6|6.930735005704536|
# +------+-----------------+
#
# √Σk=1 yk^2: 6.930735005704536
# √Σk=1 xk^2 * Σk=1 xkyk 37.96119902715072
# Centered cosine similarity between UserID 0 and UserID 6 0.08292334686093648
#
# Average rating for userId 7: 1.6296296296296295
#
# DataFrame with ratings subtracted by the average for userId 7:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      1|-0.6296296296296295|     7|
# |      2|0.37037037037037046|     7|
# |      3|-0.6296296296296295|     7|
# |      4|-0.6296296296296295|     7|
# |      7|-0.6296296296296295|     7|
# |     10|-0.6296296296296295|     7|
# |     11|0.37037037037037046|     7|
# |     14|0.37037037037037046|     7|
# |     15|-0.6296296296296295|     7|
# |     16|-0.6296296296296295|     7|
# |     18|-0.6296296296296295|     7|
# |     21|-0.6296296296296295|     7|
# |     22|-0.6296296296296295|     7|
# |     23|-0.6296296296296295|     7|
# |     25| 3.3703703703703702|     7|
# |     26|-0.6296296296296295|     7|
# |     29| 2.3703703703703702|     7|
# |     30|-0.6296296296296295|     7|
# |     31| 1.3703703703703705|     7|
# |     32|-0.6296296296296295|     7|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -0.3068783068783076
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     7|7.252075054258101|
# +------+-----------------+
#
# √Σk=1 yk^2: 7.252075054258101
# √Σk=1 xk^2 * Σk=1 xkyk 39.721250959376654
# Centered cosine similarity between UserID 0 and UserID 7 -0.0077257966319377825
#
# Average rating for userId 8: 1.8979591836734695
#
# DataFrame with ratings subtracted by the average for userId 8:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-0.8979591836734695|     8|
# |      2| 2.1020408163265305|     8|
# |      3| 0.1020408163265305|     8|
# |      4| 0.1020408163265305|     8|
# |      5|-0.8979591836734695|     8|
# |      7|-0.8979591836734695|     8|
# |      9|-0.8979591836734695|     8|
# |     11|-0.8979591836734695|     8|
# |     15|-0.8979591836734695|     8|
# |     18|-0.8979591836734695|     8|
# |     19|-0.8979591836734695|     8|
# |     21|-0.8979591836734695|     8|
# |     29| 3.1020408163265305|     8|
# |     31| 1.1020408163265305|     8|
# |     33|-0.8979591836734695|     8|
# |     35|-0.8979591836734695|     8|
# |     36|-0.8979591836734695|     8|
# |     40| 0.1020408163265305|     8|
# |     44|-0.8979591836734695|     8|
# |     45|-0.8979591836734695|     8|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: 4.956268221574343
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     8|9.406901504659615|
# +------+-----------------+
#
# √Σk=1 yk^2: 9.406901504659615
# √Σk=1 xk^2 * Σk=1 xkyk 51.523721503313624
# Centered cosine similarity between UserID 0 and UserID 8 0.09619390985287414
#
# Average rating for userId 9: 1.7924528301886793
#
# DataFrame with ratings subtracted by the average for userId 9:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.2075471698113207|     9|
# |      3|-0.7924528301886793|     9|
# |      4|-0.7924528301886793|     9|
# |      5|-0.7924528301886793|     9|
# |      6|-0.7924528301886793|     9|
# |      7| 3.2075471698113205|     9|
# |      9|-0.7924528301886793|     9|
# |     12|-0.7924528301886793|     9|
# |     14| 1.2075471698113207|     9|
# |     15|-0.7924528301886793|     9|
# |     19|-0.7924528301886793|     9|
# |     21|-0.7924528301886793|     9|
# |     22|-0.7924528301886793|     9|
# |     24|-0.7924528301886793|     9|
# |     25|-0.7924528301886793|     9|
# |     26|-0.7924528301886793|     9|
# |     30| 1.2075471698113207|     9|
# |     32| 2.2075471698113205|     9|
# |     35| 0.2075471698113207|     9|
# |     36| 0.2075471698113207|     9|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -1.6684636118598384
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     9|8.044686515463203|
# +------+-----------------+
#
# √Σk=1 yk^2: 8.044686515463203
# √Σk=1 xk^2 * Σk=1 xkyk 44.06256272576831
# Centered cosine similarity between UserID 0 and UserID 9 -0.037865786932181796
#
# Average rating for userId 10: 1.5227272727272727
#
# DataFrame with ratings subtracted by the average for userId 10:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0| 1.4772727272727273|    10|
# |      2| 2.4772727272727275|    10|
# |      4| 1.4772727272727273|    10|
# |      7|-0.5227272727272727|    10|
# |      8|-0.5227272727272727|    10|
# |     10|-0.5227272727272727|    10|
# |     13| 0.4772727272727273|    10|
# |     14|-0.5227272727272727|    10|
# |     16| 0.4772727272727273|    10|
# |     17|-0.5227272727272727|    10|
# |     18|-0.5227272727272727|    10|
# |     21|-0.5227272727272727|    10|
# |     22|-0.5227272727272727|    10|
# |     24|-0.5227272727272727|    10|
# |     25| 1.4772727272727273|    10|
# |     28|-0.5227272727272727|    10|
# |     35|-0.5227272727272727|    10|
# |     36|-0.5227272727272727|    10|
# |     37|-0.5227272727272727|    10|
# |     38|-0.5227272727272727|    10|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: 6.318181818181817
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    10|5.914158666054939|
# +------+-----------------+
#
# √Σk=1 yk^2: 5.914158666054939
# √Σk=1 xk^2 * Σk=1 xkyk 32.39318110062954
# Centered cosine similarity between UserID 0 and UserID 10 0.19504666116471736
#
# Average rating for userId 11: 2.2857142857142856
#
# DataFrame with ratings subtracted by the average for userId 11:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-1.2857142857142856|    11|
# |      6|-0.2857142857142856|    11|
# |      9|-1.2857142857142856|    11|
# |     10|-1.2857142857142856|    11|
# |     11|-1.2857142857142856|    11|
# |     12|-1.2857142857142856|    11|
# |     13| 1.7142857142857144|    11|
# |     16|-1.2857142857142856|    11|
# |     18| 2.7142857142857144|    11|
# |     19| 1.7142857142857144|    11|
# |     20|-1.2857142857142856|    11|
# |     21|-1.2857142857142856|    11|
# |     22|-1.2857142857142856|    11|
# |     23| 2.7142857142857144|    11|
# |     25|-1.2857142857142856|    11|
# |     27| 2.7142857142857144|    11|
# |     30| 2.7142857142857144|    11|
# |     32| 2.7142857142857144|    11|
# |     35| 0.7142857142857144|    11|
# |     36|-0.2857142857142856|    11|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -14.26530612244898
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    11|11.464230084422212|
# +------+------------------+
#
# √Σk=1 yk^2: 11.464230084422212
# √Σk=1 xk^2 * Σk=1 xkyk 62.792174216674034
# Centered cosine similarity between UserID 0 and UserID 11 -0.22718286634293552
#
# Average rating for userId 12: 1.8545454545454545
#
# DataFrame with ratings subtracted by the average for userId 12:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2|-0.8545454545454545|    12|
# |      4|-0.8545454545454545|    12|
# |      6|-0.8545454545454545|    12|
# |      7| 1.1454545454545455|    12|
# |      8|-0.8545454545454545|    12|
# |     14|-0.8545454545454545|    12|
# |     15| 0.1454545454545455|    12|
# |     16| 2.1454545454545455|    12|
# |     17| 3.1454545454545455|    12|
# |     18| 0.1454545454545455|    12|
# |     21|-0.8545454545454545|    12|
# |     22| 0.1454545454545455|    12|
# |     23| 1.1454545454545455|    12|
# |     24|-0.8545454545454545|    12|
# |     25|-0.8545454545454545|    12|
# |     27| 3.1454545454545455|    12|
# |     30| 0.1454545454545455|    12|
# |     31| 2.1454545454545455|    12|
# |     35| 3.1454545454545455|    12|
# |     38|-0.8545454545454545|    12|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -8.225974025974025
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    12|9.425304432025719|
# +------+-----------------+
#
# √Σk=1 yk^2: 9.425304432025719
# √Σk=1 xk^2 * Σk=1 xkyk 51.62451848773907
# Centered cosine similarity between UserID 0 and UserID 12 -0.1593423874341358
#
# Average rating for userId 13: 1.5208333333333333
#
# DataFrame with ratings subtracted by the average for userId 13:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-0.5208333333333333|    13|
# |      3|-0.5208333333333333|    13|
# |      4|0.47916666666666674|    13|
# |      5|-0.5208333333333333|    13|
# |      6|-0.5208333333333333|    13|
# |     12|-0.5208333333333333|    13|
# |     14|0.47916666666666674|    13|
# |     15|-0.5208333333333333|    13|
# |     17|-0.5208333333333333|    13|
# |     18| 1.4791666666666667|    13|
# |     20|-0.5208333333333333|    13|
# |     21|-0.5208333333333333|    13|
# |     22|-0.5208333333333333|    13|
# |     26|-0.5208333333333333|    13|
# |     27|-0.5208333333333333|    13|
# |     29| 1.4791666666666667|    13|
# |     31|-0.5208333333333333|    13|
# |     33|-0.5208333333333333|    13|
# |     40|0.47916666666666674|    13|
# |     43|0.47916666666666674|    13|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -0.4017857142857145
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    13|5.475323430325067|
# +------+-----------------+
#
# √Σk=1 yk^2: 5.475323430325067
# √Σk=1 xk^2 * Σk=1 xkyk 29.98958152425606
# Centered cosine similarity between UserID 0 and UserID 13 -0.013397509863908695
#
# Average rating for userId 14: 1.7894736842105263
#
# DataFrame with ratings subtracted by the average for userId 14:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      1|-0.7894736842105263|    14|
# |      3| 1.2105263157894737|    14|
# |      4|-0.7894736842105263|    14|
# |      5|-0.7894736842105263|    14|
# |      6|-0.7894736842105263|    14|
# |      7|-0.7894736842105263|    14|
# |      9|-0.7894736842105263|    14|
# |     10|-0.7894736842105263|    14|
# |     11|-0.7894736842105263|    14|
# |     12|-0.7894736842105263|    14|
# |     13|-0.7894736842105263|    14|
# |     14| 1.2105263157894737|    14|
# |     15|-0.7894736842105263|    14|
# |     16|-0.7894736842105263|    14|
# |     17|-0.7894736842105263|    14|
# |     20|-0.7894736842105263|    14|
# |     21|-0.7894736842105263|    14|
# |     24|-0.7894736842105263|    14|
# |     25|0.21052631578947367|    14|
# |     27|-0.7894736842105263|    14|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -3.1278195488721803
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+----------------+
# |userId|sqrt_sum_ratings|
# +------+----------------+
# |    14|9.56418758758559|
# +------+----------------+
#
# √Σk=1 yk^2: 9.56418758758559
# √Σk=1 xk^2 * Σk=1 xkyk 52.385212859315466
# Centered cosine similarity between UserID 0 and UserID 14 -0.05970806222114972
#
# Average rating for userId 15: 1.5416666666666667
#
# DataFrame with ratings subtracted by the average for userId 15:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-0.5416666666666667|    15|
# |      1|  2.458333333333333|    15|
# |      2|-0.5416666666666667|    15|
# |      5|0.45833333333333326|    15|
# |      6|-0.5416666666666667|    15|
# |      7|-0.5416666666666667|    15|
# |     13|-0.5416666666666667|    15|
# |     14|-0.5416666666666667|    15|
# |     15|-0.5416666666666667|    15|
# |     17|0.45833333333333326|    15|
# |     19|0.45833333333333326|    15|
# |     22|0.45833333333333326|    15|
# |     23|0.45833333333333326|    15|
# |     25|-0.5416666666666667|    15|
# |     26| 1.4583333333333333|    15|
# |     27|-0.5416666666666667|    15|
# |     28|0.45833333333333326|    15|
# |     29|-0.5416666666666667|    15|
# |     32|-0.5416666666666667|    15|
# |     33|0.45833333333333326|    15|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: 0.8333333333333335
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    15|5.993051532121735|
# +------+-----------------+
#
# √Σk=1 yk^2: 5.993051532121735
# √Σk=1 xk^2 * Σk=1 xkyk 32.825295124339725
# Centered cosine similarity between UserID 0 and UserID 15 0.025386925850224045
#
# Average rating for userId 16: 1.7777777777777777
#
# DataFrame with ratings subtracted by the average for userId 16:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2|-0.7777777777777777|    16|
# |      5| 1.2222222222222223|    16|
# |      6|0.22222222222222232|    16|
# |      7|-0.7777777777777777|    16|
# |      9|-0.7777777777777777|    16|
# |     12|-0.7777777777777777|    16|
# |     14|-0.7777777777777777|    16|
# |     15|-0.7777777777777777|    16|
# |     19|-0.7777777777777777|    16|
# |     21|0.22222222222222232|    16|
# |     29| 2.2222222222222223|    16|
# |     30|0.22222222222222232|    16|
# |     32|-0.7777777777777777|    16|
# |     34|-0.7777777777777777|    16|
# |     36|-0.7777777777777777|    16|
# |     38|-0.7777777777777777|    16|
# |     46|-0.7777777777777777|    16|
# |     47| 1.2222222222222223|    16|
# |     48|-0.7777777777777777|    16|
# |     49|-0.7777777777777777|    16|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -6.73015873015873
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+----------------+
# |userId|sqrt_sum_ratings|
# +------+----------------+
# |    16|8.47217668475922|
# +------+----------------+
#
# √Σk=1 yk^2: 8.47217668475922
# √Σk=1 xk^2 * Σk=1 xkyk 46.404022814119614
# Centered cosine similarity between UserID 0 and UserID 16 -0.14503395011931824
#
# Average rating for userId 17: 1.9565217391304348
#
# DataFrame with ratings subtracted by the average for userId 17:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2|-0.9565217391304348|    17|
# |      3|-0.9565217391304348|    17|
# |      6|-0.9565217391304348|    17|
# |     10| 2.0434782608695654|    17|
# |     11|-0.9565217391304348|    17|
# |     13|0.04347826086956519|    17|
# |     17| 3.0434782608695654|    17|
# |     19|-0.9565217391304348|    17|
# |     20| 3.0434782608695654|    17|
# |     22| 2.0434782608695654|    17|
# |     28|-0.9565217391304348|    17|
# |     29|-0.9565217391304348|    17|
# |     33|-0.9565217391304348|    17|
# |     34|-0.9565217391304348|    17|
# |     35|0.04347826086956519|    17|
# |     37|-0.9565217391304348|    17|
# |     38|-0.9565217391304348|    17|
# |     45|-0.9565217391304348|    17|
# |     46| 3.0434782608695654|    17|
# |     47|-0.9565217391304348|    17|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -4.13664596273292
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    17|9.690874237046984|
# +------+-----------------+
#
# √Σk=1 yk^2: 9.690874237046984
# √Σk=1 xk^2 * Σk=1 xkyk 53.07910421576302
# Centered cosine similarity between UserID 0 and UserID 17 -0.07793360539615984
#
# Average rating for userId 18: 1.7307692307692308
#
# DataFrame with ratings subtracted by the average for userId 18:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      1|-0.7307692307692308|    18|
# |      4| 1.2692307692307692|    18|
# |      5|0.26923076923076916|    18|
# |      6|-0.7307692307692308|    18|
# |      7|-0.7307692307692308|    18|
# |     10|-0.7307692307692308|    18|
# |     11|  2.269230769230769|    18|
# |     12|0.26923076923076916|    18|
# |     13|-0.7307692307692308|    18|
# |     15|-0.7307692307692308|    18|
# |     18|-0.7307692307692308|    18|
# |     20|-0.7307692307692308|    18|
# |     21|0.26923076923076916|    18|
# |     22|-0.7307692307692308|    18|
# |     23|0.26923076923076916|    18|
# |     25|-0.7307692307692308|    18|
# |     26|-0.7307692307692308|    18|
# |     27|-0.7307692307692308|    18|
# |     28|  3.269230769230769|    18|
# |     29|-0.7307692307692308|    18|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -3.335164835164835
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    18|8.957163012403493|
# +------+-----------------+
#
# √Σk=1 yk^2: 8.957163012403493
# √Σk=1 xk^2 * Σk=1 xkyk 49.060402331443214
# Centered cosine similarity between UserID 0 and UserID 18 -0.0679807885111309
#
# Average rating for userId 19: 1.469387755102041
#
# DataFrame with ratings subtracted by the average for userId 19:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-0.4693877551020409|    19|
# |      1|-0.4693877551020409|    19|
# |      2|-0.4693877551020409|    19|
# |      4|-0.4693877551020409|    19|
# |      6| 0.5306122448979591|    19|
# |     11|-0.4693877551020409|    19|
# |     12|-0.4693877551020409|    19|
# |     14|-0.4693877551020409|    19|
# |     23|-0.4693877551020409|    19|
# |     26|-0.4693877551020409|    19|
# |     31|-0.4693877551020409|    19|
# |     32| 2.5306122448979593|    19|
# |     33|-0.4693877551020409|    19|
# |     34|-0.4693877551020409|    19|
# |     37|-0.4693877551020409|    19|
# |     38|-0.4693877551020409|    19|
# |     41|-0.4693877551020409|    19|
# |     43|-0.4693877551020409|    19|
# |     45|-0.4693877551020409|    19|
# |     48|-0.4693877551020409|    19|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -3.53935860058309
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    19|6.340668863192042|
# +------+-----------------+
#
# √Σk=1 yk^2: 6.340668863192042
# √Σk=1 xk^2 * Σk=1 xkyk 34.72927366040921
# Centered cosine similarity between UserID 0 and UserID 19 -0.10191283109436
#
# Average rating for userId 20: 1.7659574468085106
#
# DataFrame with ratings subtracted by the average for userId 20:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-0.7659574468085106|    20|
# |      1|-0.7659574468085106|    20|
# |      2|0.23404255319148937|    20|
# |      4|0.23404255319148937|    20|
# ...
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -9.969780219780215
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    23|10.679779600145888|
# +------+------------------+
#
# √Σk=1 yk^2: 10.679779600145888
# √Σk=1 xk^2 * Σk=1 xkyk 58.49556196183409
# Centered cosine similarity between UserID 0 and UserID 23 -0.17043652347993649
#
# Average rating for userId 24: 1.8846153846153846
#
# DataFrame with ratings subtracted by the average for userId 24:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      4|-0.8846153846153846|    24|
# |      6| 1.1153846153846154|    24|
# |      7|-0.8846153846153846|    24|
# |     10|0.11538461538461542|    24|
# |     12|-0.8846153846153846|    24|
# |     15|-0.8846153846153846|    24|
# |     19|-0.8846153846153846|    24|
# |     24|-0.8846153846153846|    24|
# |     27| 1.1153846153846154|    24|
# |     30| 3.1153846153846154|    24|
# |     31|-0.8846153846153846|    24|
# |     32| 1.1153846153846154|    24|
# |     33|-0.8846153846153846|    24|
# |     37|-0.8846153846153846|    24|
# |     39|-0.8846153846153846|    24|
# |     40|-0.8846153846153846|    24|
# |     42|-0.8846153846153846|    24|
# |     43| 1.1153846153846154|    24|
# |     45|0.11538461538461542|    24|
# |     46|-0.8846153846153846|    24|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -3.6868131868131866
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+----------------+
# |userId|sqrt_sum_ratings|
# +------+----------------+
# |    24|9.96532449585523|
# +------+----------------+
#
# √Σk=1 yk^2: 9.96532449585523
# √Σk=1 xk^2 * Σk=1 xkyk 54.58233019238709
# Centered cosine similarity between UserID 0 and UserID 24 -0.06754591044058078
#
# Average rating for userId 25: 1.5869565217391304
#
# DataFrame with ratings subtracted by the average for userId 25:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      1| 1.4130434782608696|    25|
# |      2|-0.5869565217391304|    25|
# |      7|-0.5869565217391304|    25|
# |      9|-0.5869565217391304|    25|
# |     12| 1.4130434782608696|    25|
# |     16| 1.4130434782608696|    25|
# |     17|-0.5869565217391304|    25|
# |     18|-0.5869565217391304|    25|
# |     20|-0.5869565217391304|    25|
# |     22|-0.5869565217391304|    25|
# |     23|-0.5869565217391304|    25|
# |     26| 0.4130434782608696|    25|
# |     29|-0.5869565217391304|    25|
# |     30|-0.5869565217391304|    25|
# |     31| 0.4130434782608696|    25|
# |     33| 2.4130434782608696|    25|
# |     34| 1.4130434782608696|    25|
# |     35| 0.4130434782608696|    25|
# |     36|-0.5869565217391304|    25|
# |     37|-0.5869565217391304|    25|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -1.6242236024844716
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    25|6.257169800560272|
# +------+-----------------+
#
# √Σk=1 yk^2: 6.257169800560272
# √Σk=1 xk^2 * Σk=1 xkyk 34.27193045906964
# Centered cosine similarity between UserID 0 and UserID 25 -0.04739224142696757
#
# Average rating for userId 26: 2.204081632653061
#
# DataFrame with ratings subtracted by the average for userId 26:
# +-------+------------------+------+
# |movieId|            rating|userId|
# +-------+------------------+------+
# |      0|-1.204081632653061|    26|
# |      1|-1.204081632653061|    26|
# |      2|-1.204081632653061|    26|
# |      3|-1.204081632653061|    26|
# |      4| 1.795918367346939|    26|
# |      5|-0.204081632653061|    26|
# |      6| 0.795918367346939|    26|
# |      7| 2.795918367346939|    26|
# |     13| 0.795918367346939|    26|
# |     14|-1.204081632653061|    26|
# |     16|-1.204081632653061|    26|
# |     18| 0.795918367346939|    26|
# |     20|-1.204081632653061|    26|
# |     21| 0.795918367346939|    26|
# |     22| 2.795918367346939|    26|
# |     23| 2.795918367346939|    26|
# |     24| 2.795918367346939|    26|
# |     27|-1.204081632653061|    26|
# |     31|-1.204081632653061|    26|
# |     35|-1.204081632653061|    26|
# +-------+------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -4.938775510204082
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+------------------+
# |userId|  sqrt_sum_ratings|
# +------+------------------+
# |    26|10.293647734086758|
# +------+------------------+
#
# √Σk=1 yk^2: 10.293647734086758
# √Σk=1 xk^2 * Σk=1 xkyk 56.3806306297126
# Centered cosine similarity between UserID 0 and UserID 26 -0.08759702498966634
#
# Average rating for userId 27: 1.608695652173913
#
# DataFrame with ratings subtracted by the average for userId 27:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|-0.6086956521739131|    27|
# |      9|-0.6086956521739131|    27|
# |     10|-0.6086956521739131|    27|
# |     18|  2.391304347826087|    27|
# |     19|  1.391304347826087|    27|
# |     20|-0.6086956521739131|    27|
# |     22| 0.3913043478260869|    27|
# |     24| 0.3913043478260869|    27|
# |     25|-0.6086956521739131|    27|
# |     27|  1.391304347826087|    27|
# |     28|-0.6086956521739131|    27|
# |     29|-0.6086956521739131|    27|
# |     31|-0.6086956521739131|    27|
# |     33|  1.391304347826087|    27|
# |     40|-0.6086956521739131|    27|
# |     42|-0.6086956521739131|    27|
# |     43|-0.6086956521739131|    27|
# |     44|  1.391304347826087|    27|
# |     45|-0.6086956521739131|    27|
# |     51|  1.391304347826087|    27|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -7.732919254658383
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+----------------+
# |userId|sqrt_sum_ratings|
# +------+----------------+
# |    27|6.07918758874329|
# +------+----------------+
#
# √Σk=1 yk^2: 6.07918758874329
# √Σk=1 xk^2 * Σk=1 xkyk 33.297081736601406
# Centered cosine similarity between UserID 0 and UserID 27 -0.23224014992755557
#
# Average rating for userId 28: 1.82
#
# DataFrame with ratings subtracted by the average for userId 28:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      0|               1.18|    28|
# |      1|-0.8200000000000001|    28|
# |      2| 2.1799999999999997|    28|
# |      3|-0.8200000000000001|    28|
# |      6|-0.8200000000000001|    28|
# |      7|-0.8200000000000001|    28|
# |     12| 3.1799999999999997|    28|
# |     13|0.17999999999999994|    28|
# |     14|-0.8200000000000001|    28|
# |     15|-0.8200000000000001|    28|
# |     17|-0.8200000000000001|    28|
# |     19|               1.18|    28|
# |     20|-0.8200000000000001|    28|
# |     23|               1.18|    28|
# |     24|               1.18|    28|
# |     27|-0.8200000000000001|    28|
# |     29|-0.8200000000000001|    28|
# |     33|-0.8200000000000001|    28|
# |     34|-0.8200000000000001|    28|
# |     36|-0.8200000000000001|    28|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: 17.388571428571424
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    28|8.909545442950499|
# +------+-----------------+
#
# √Σk=1 yk^2: 8.909545442950499
# √Σk=1 xk^2 * Σk=1 xkyk 48.79959016221348
# Centered cosine similarity between UserID 0 and UserID 28 0.35632617755129736
#
# Average rating for userId 29: 1.826086956521739
#
# DataFrame with ratings subtracted by the average for userId 29:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      3| -0.826086956521739|    29|
# |      4| -0.826086956521739|    29|
# |      5| -0.826086956521739|    29|
# |      7|0.17391304347826098|    29|
# |      9| -0.826086956521739|    29|
# |     10|  1.173913043478261|    29|
# |     11| -0.826086956521739|    29|
# |     13|  1.173913043478261|    29|
# |     14| -0.826086956521739|    29|
# |     15| -0.826086956521739|    29|
# |     17|  1.173913043478261|    29|
# |     19|  1.173913043478261|    29|
# |     22|  1.173913043478261|    29|
# |     23| 2.1739130434782608|    29|
# |     25| -0.826086956521739|    29|
# |     29| -0.826086956521739|    29|
# |     31| -0.826086956521739|    29|
# |     32| 2.1739130434782608|    29|
# |     33|0.17391304347826098|    29|
# |     36|0.17391304347826098|    29|
# +-------+-------------------+------+
# only showing top 20 rows
#
#
# Combined DataFrame:
# +-------+-------------------+------+
# |movieId|             rating|userId|
# +-------+-------------------+------+
# |      2| 1.5714285714285714|     0|
# |      3|-0.4285714285714286|     0|
# |      5| 0.5714285714285714|     0|
# |      9|  2.571428571428571|     0|
# |     11|-0.4285714285714286|     0|
# |     12| 0.5714285714285714|     0|
# |     15|-0.4285714285714286|     0|
# |     17|-0.4285714285714286|     0|
# |     19|-0.4285714285714286|     0|
# |     21|-0.4285714285714286|     0|
# |     23|-0.4285714285714286|     0|
# |     26| 1.5714285714285714|     0|
# |     27|-0.4285714285714286|     0|
# |     28|-0.4285714285714286|     0|
# |     29|-0.4285714285714286|     0|
# |     30|-0.4285714285714286|     0|
# |     31|-0.4285714285714286|     0|
# |     34|-0.4285714285714286|     0|
# |     37|-0.4285714285714286|     0|
# |     41| 0.5714285714285714|     0|
# +-------+-------------------+------+
# only showing top 20 rows
#
# Σk=1 xkyk: -5.236024844720495
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |     0|5.477225575051664|
# +------+-----------------+
#
# √Σk=1 xk^2: 5.477225575051664
# +------+-----------------+
# |userId| sqrt_sum_ratings|
# +------+-----------------+
# |    29|7.655631629863987|
# +------+-----------------+
#
# √Σk=1 yk^2: 7.655631629863987
# √Σk=1 xk^2 * Σk=1 xkyk 41.93162135626548
# Centered cosine similarity between UserID 0 and UserID 29 -0.1248705553318205

# %%
print("User ID with the highest Centered Cosine similarity to UserID", user_input, "is:", max_similarity_user)
print("Highest Centered Cosine Similarity:", max_similarity)
# Out:
# User ID with the highest Centered Cosine similarity to UserID 0 is: 28
# Highest Centered Cosine Similarity: 0.35632617755129736

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg
from pyspark.ml.evaluation import RegressionEvaluator
file_path = "/content/12_movielens_ratings.csv"
df = spark.read.csv(file_path, header=True, inferSchema=True)
(training, test) = df.randomSplit([0.8, 0.2])
mean_ratings = training.groupBy("movieId").agg(avg("rating").alias("mean_rating"))
predictions = test.join(mean_ratings, "movieId", "left_outer")
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating", predictionCol="mean_rating")
rmse = evaluator.evaluate(predictions)
print(f"Root Mean Squared Error (RMSE): {rmse}")

top_predictions = mean_ratings.orderBy("mean_rating", ascending=False).limit(10)
precision_at_10 = top_predictions \
    .join(df.select("movieId", "rating"), "movieId") \
    .rdd.map(lambda x: abs(x[2] - x[1]) <= 0.5) \
    .reduce(lambda x, y: x + y) / top_predictions.count()
print(f"Precision at Top 10: {precision_at_10}")
# Out:
# Root Mean Squared Error (RMSE): 1.2414524134909568
# Precision at Top 10: 2.4

# %%
from pyspark.ml.feature import StringIndexer, VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg
from pyspark.ml.evaluation import RegressionEvaluator
file_path = "/content/12_movielens_ratings.csv"
df = spark.read.csv(file_path, header=True, inferSchema=True)

df = df.withColumn("label", (col("rating") >= 3.0).cast("double"))
feature_cols = ["userId", "movieId"]
assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
df = assembler.transform(df)
(training, test) = df.randomSplit([0.8, 0.2])
lr = LogisticRegression(featuresCol="features", labelCol="label")
model = lr.fit(training)
predictions = model.transform(test)
evaluator = BinaryClassificationEvaluator(labelCol="label", rawPredictionCol="rawPrediction", metricName="areaUnderROC")
roc_auc = evaluator.evaluate(predictions)
print(f"Area under ROC curve: {roc_auc}")
precision = predictions.filter("prediction = label").count() / predictions.count()
print(f"Precision: {precision}")
coverage = predictions.select("movieId").distinct().count() / df.select("movieId").distinct().count()
print(f"Coverage: {coverage}")
# Out:
# Area under ROC curve: 0.5909657320872275
# Precision: 0.781021897810219
# Coverage: 0.96
